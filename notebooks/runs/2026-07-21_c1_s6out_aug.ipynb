# %% [markdown]
# # 03 — Training runner, pre-configured: `c1_ce_s6out_aug` (C1-aug arm, S6-out, seed 42)
#
# A copy of the `03_train` template with `RUN` pre-set — open, run all.
#
# **What this run is** (team-approved 2026-07-20; pre-registered in
# `configs/c1_ce_s6out_aug.yaml` + `splits/CHANGELOG.md`): the
# cross-rotation replication of the C1-aug arm on the frozen E2'
# living-out split (`splits/p2_living.json`, test = S6, lab S7 in
# train) — prioritized over a second seed because rotation specificity
# is the residual confound once pairing cancels the seed nuisance.
# Paired against the existing `C1_s6out` run. Reminder: this rotation's
# val is 6 traces / 5 classes and very noisy — the deliverable is the
# val-selected `best.ckpt` for the single §0.7 test row, never the val
# number.
#
# **Requires**: the frozen `splits/p2_living.json` in the clone (asserted
# at launch) and write access to your `ckpt_root` (the run creates
# `C1_s6out_aug/` — separate from `C1_s6out/`). The launch-check cell
# below fails on a stale clone (unknown `ce_amp` profile) BEFORE any
# training starts.
#
# Archive the executed copy under `notebooks/runs/` as
# `YYYY-MM-DD_c1_ce_s6out_aug.ipynb`, as for every run.

# %% [markdown]
# ## Environment setup
#
# This notebook is not one run per file. Instead:
#
# - one notebook = one runner
# - one config = one experiment
# - different people can use the same notebook with different config values
#
# In Colab, the notebook runs on a remote VM. If the repo is not already
# available there, this notebook will clone it from GitHub. It also stages
# data from the shared Drive archive into `/content/data` using the
# paths defined in `configs/paths.yaml`.

# %%
from pathlib import Path
import subprocess
import sys
import torch
import zipfile

REPO_URL = "https://github.com/FilippoIsoni/sharp-har.git"

# Locate or clone the repository root containing the sharp_har package.
# In Colab, the notebook may run from a temporary working directory.
cwd = Path.cwd().resolve()
if (cwd / "sharp_har").exists():
    REPO_DIR = cwd
elif (cwd.parent / "sharp_har").exists():
    REPO_DIR = cwd.parent
elif (cwd.parent.parent / "sharp_har").exists():
    REPO_DIR = cwd.parent.parent
else:
    REPO_DIR = Path("/content/sharp-har")
    if not REPO_DIR.exists():
        REPO_DIR.parent.mkdir(parents=True, exist_ok=True)
        subprocess.run(["git", "clone", REPO_URL, str(REPO_DIR)], check=True)

# After the clone, so the file actually exists on a fresh runtime.
# !pip install -q -r {REPO_DIR}/requirements.txt

sys.path.insert(0, str(REPO_DIR))

from google.colab import drive
from sharp_har.train import train_run
from sharp_har.utils import read_yaml

paths_cfg = read_yaml(REPO_DIR / "configs" / "paths.yaml")
drive_root = Path(paths_cfg["drive_root"])
stage_dir = Path(paths_cfg["stage_dir"])
CKPT_ROOT = Path(paths_cfg["ckpt_root"])

# Mount Drive unconditionally (idempotent): checkpoints are written to
# CKPT_ROOT on Drive even when the data is already staged on the VM.
drive.mount("/content/drive")

# Stage the zip archives if needed (same convention as 00_setup_smoke).
if not (stage_dir.exists() and any(stage_dir.rglob("*.txt"))):
    stage_dir.mkdir(parents=True, exist_ok=True)
    for zip_name in paths_cfg["zips"]:
        src = drive_root / zip_name
        dst = Path("/content") / zip_name
        print(f"copying {src} -> {dst}")
        subprocess.run(["cp", str(src), str(dst)], check=True)
        with zipfile.ZipFile(dst) as zf:
            zf.extractall(stage_dir)

print("Repo dir:", REPO_DIR)
print("sharp_har exists:", (REPO_DIR / "sharp_har").exists())
print("GPU available:", torch.cuda.is_available())
print("Stage dir:", stage_dir)
print("Checkpoint root:", CKPT_ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Repo dir: /content/sharp-har
# sharp_har exists: True
# GPU available: True
# Stage dir: /content/data
# Checkpoint root: /content/drive/MyDrive/sharp_har_runs

# %%
# GPU sanity check - run BEFORE launching training (see the C3 OOM incident).
# Expected on a clean runtime: no processes listed, ~0 MiB used. If not:
# Runtime -> Disconnect and delete runtime, then rerun from the top.
# !nvidia-smi

import torch
free, total = torch.cuda.mem_get_info()
print(f"free: {free/2**30:.2f} GiB / total: {total/2**30:.2f} GiB")
assert free / 2**30 > 10, (
    "GPU is not clean: less than 10 GiB free before training. "
    "Something else is holding memory - delete the runtime and start over."
)
print("GPU clean - OK to launch.")
# Out:
# Tue Jul 21 07:44:41 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   53C    P0             28W /   70W |     105MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A             532      C   /usr/bin/python3                        102MiB |
# +-----------------------------------------------------------------------------------------+
# free: 14.46 GiB / total: 14.56 GiB
# GPU clean - OK to launch.

# %%
# Launch check (C1-aug arm): the clone must know the additive ce_amp
# profile (§3 amendment 2026-07-20) with the pre-registered values, and
# the frozen ce profile must be untouched. A stale clone fails HERE,
# not mid-run.
from sharp_har.augment import augment_cfg

_amp = augment_cfg("ce_amp")
assert _amp["p_amplitude_scaling"] == 0.8 and _amp["amplitude_range"] == (0.6, 1.5), _amp
_ce = augment_cfg("ce")
assert _ce["p_amplitude_scaling"] == 0.5 and _ce["amplitude_range"] == (0.8, 1.2), _ce
print("ce_amp profile OK:", {k: _amp[k] for k in ("p_amplitude_scaling", "amplitude_range")})
# Out:
# ce_amp profile OK: {'p_amplitude_scaling': 0.8, 'amplitude_range': (0.6, 1.5)}

# %% [markdown]
# ## Load config and launch the run
#
# Choose one config stem below and run the cell. The config name
# determines which experiment is executed.

# %%
RUN = "c1_ce_s6out_aug"  # pre-registered C1-aug arm (S6-out, seed 42) - do not change in-session
cfg = read_yaml(REPO_DIR / "configs" / f"{RUN}.yaml")
assert cfg["train"].get("augment_profile") == "ce_amp", cfg["train"]
assert (REPO_DIR / cfg["split_file"]).exists(), f"frozen {cfg['split_file']} missing from the clone (§0.1)"

print("Selected run:", RUN)
print("Config summary:")
print(cfg)

out = train_run(cfg, stage_dir=stage_dir, ckpt_dir=CKPT_ROOT, repo_dir=REPO_DIR)
print("Train run finished:", out)
# Out:
# 2026-07-21 07:44:42,022 [INFO] sharp_har.data: train: 80 traces, 50948 (window, antenna) samples (win=340, stride=100)
# Selected run: c1_ce_s6out_aug
# Config summary:
# {'name': 'C1_s6out_aug', 'seed': 42, 'protocol': 'P2-living', 'split_file': 'splits/p2_living.json', 'backbone': 'resnet_vb', 'd_enc': 256, 'n_att': 8, 'loss': {'type': 'ce', 'label_smoothing': 0.1}, 'adversary': {'type': None, 'target': 'ar_set', 'lambda_max': None, 'beta': None}, 'optim': {'name': 'adamw', 'lr': 0.001, 'wd': 0.0001, 'warmup_epochs': 5, 'scheduler': 'cosine'}, 'train': {'epoch_steps': 400, 'max_epochs': 40, 'batch_size': 256, 'sampler': 'uniform', 'augment_profile': 'ce_amp', 'amp': True, 'grad_clip': 1.0}, 'eval': {'select_metric': 'val_macro_f1', 'patience': 10}}
# 2026-07-21 07:44:42,038 [INFO] sharp_har.data: val: 6 traces, 956 (window, antenna) samples (win=340, stride=340)
# 2026-07-21 07:49:00,233 [INFO] sharp_har.train: C1_s6out_aug epoch 1/40: loss 1.6096, val macro-F1 0.3389, 0.615 s/step
# 2026-07-21 07:52:44,072 [INFO] sharp_har.train: C1_s6out_aug epoch 2/40: loss 1.3898, val macro-F1 0.1950, 0.554 s/step
# 2026-07-21 07:56:25,673 [INFO] sharp_har.train: C1_s6out_aug epoch 3/40: loss 1.2814, val macro-F1 0.5402, 0.548 s/step
# 2026-07-21 08:00:07,512 [INFO] sharp_har.train: C1_s6out_aug epoch 4/40: loss 1.2287, val macro-F1 0.3417, 0.549 s/step
# 2026-07-21 08:03:49,621 [INFO] sharp_har.train: C1_s6out_aug epoch 5/40: loss 1.2176, val macro-F1 0.4073, 0.551 s/step
# 2026-07-21 08:07:31,386 [INFO] sharp_har.train: C1_s6out_aug epoch 6/40: loss 1.1358, val macro-F1 0.3434, 0.550 s/step
# 2026-07-21 08:11:14,152 [INFO] sharp_har.train: C1_s6out_aug epoch 7/40: loss 1.0886, val macro-F1 0.4034, 0.553 s/step
# 2026-07-21 08:14:55,950 [INFO] sharp_har.train: C1_s6out_aug epoch 8/40: loss 1.0626, val macro-F1 0.8463, 0.549 s/step
# 2026-07-21 08:18:37,754 [INFO] sharp_har.train: C1_s6out_aug epoch 9/40: loss 1.0212, val macro-F1 0.6736, 0.549 s/step
# 2026-07-21 08:22:19,418 [INFO] sharp_har.train: C1_s6out_aug epoch 10/40: loss 0.9865, val macro-F1 0.4318, 0.549 s/step
# 2026-07-21 08:26:00,111 [INFO] sharp_har.train: C1_s6out_aug epoch 11/40: loss 0.9569, val macro-F1 0.4744, 0.548 s/step
# 2026-07-21 08:29:41,475 [INFO] sharp_har.train: C1_s6out_aug epoch 12/40: loss 0.9389, val macro-F1 0.4984, 0.549 s/step
# 2026-07-21 08:33:23,355 [INFO] sharp_har.train: C1_s6out_aug epoch 13/40: loss 0.9092, val macro-F1 0.7126, 0.550 s/step
# 2026-07-21 08:37:04,985 [INFO] sharp_har.train: C1_s6out_aug epoch 14/40: loss 0.8809, val macro-F1 0.7368, 0.549 s/step
# 2026-07-21 08:40:45,084 [INFO] sharp_har.train: C1_s6out_aug epoch 15/40: loss 0.8504, val macro-F1 0.8586, 0.544 s/step
# 2026-07-21 08:44:26,061 [INFO] sharp_har.train: C1_s6out_aug epoch 16/40: loss 0.8236, val macro-F1 0.5399, 0.547 s/step
# 2026-07-21 08:48:06,393 [INFO] sharp_har.train: C1_s6out_aug epoch 17/40: loss 0.7971, val macro-F1 0.6793, 0.546 s/step
# 2026-07-21 08:51:47,702 [INFO] sharp_har.train: C1_s6out_aug epoch 18/40: loss 0.7722, val macro-F1 0.8902, 0.548 s/step
# 2026-07-21 08:55:29,190 [INFO] sharp_har.train: C1_s6out_aug epoch 19/40: loss 0.7471, val macro-F1 0.3231, 0.548 s/step
# 2026-07-21 08:59:11,915 [INFO] sharp_har.train: C1_s6out_aug epoch 20/40: loss 0.7255, val macro-F1 0.6044, 0.550 s/step
# 2026-07-21 09:02:53,099 [INFO] sharp_har.train: C1_s6out_aug epoch 21/40: loss 0.6985, val macro-F1 0.8471, 0.548 s/step
# 2026-07-21 09:06:33,354 [INFO] sharp_har.train: C1_s6out_aug epoch 22/40: loss 0.6856, val macro-F1 0.4918, 0.546 s/step
# 2026-07-21 09:10:13,385 [INFO] sharp_har.train: C1_s6out_aug epoch 23/40: loss 0.6754, val macro-F1 0.9015, 0.546 s/step
# 2026-07-21 09:13:54,365 [INFO] sharp_har.train: C1_s6out_aug epoch 24/40: loss 0.6614, val macro-F1 0.7979, 0.547 s/step
# 2026-07-21 09:17:35,680 [INFO] sharp_har.train: C1_s6out_aug epoch 25/40: loss 0.6518, val macro-F1 0.6855, 0.548 s/step
# 2026-07-21 09:21:16,828 [INFO] sharp_har.train: C1_s6out_aug epoch 26/40: loss 0.6442, val macro-F1 0.7867, 0.548 s/step
# 2026-07-21 09:24:57,734 [INFO] sharp_har.train: C1_s6out_aug epoch 27/40: loss 0.6327, val macro-F1 0.9141, 0.548 s/step
# 2026-07-21 09:28:37,941 [INFO] sharp_har.train: C1_s6out_aug epoch 28/40: loss 0.6268, val macro-F1 0.7274, 0.546 s/step
# 2026-07-21 09:32:18,433 [INFO] sharp_har.train: C1_s6out_aug epoch 29/40: loss 0.6182, val macro-F1 0.6864, 0.546 s/step
# 2026-07-21 09:35:59,614 [INFO] sharp_har.train: C1_s6out_aug epoch 30/40: loss 0.6128, val macro-F1 0.5873, 0.547 s/step
# 2026-07-21 09:39:40,181 [INFO] sharp_har.train: C1_s6out_aug epoch 31/40: loss 0.6052, val macro-F1 0.9222, 0.547 s/step
# 2026-07-21 09:43:21,116 [INFO] sharp_har.train: C1_s6out_aug epoch 32/40: loss 0.6021, val macro-F1 0.8899, 0.547 s/step
# 2026-07-21 09:47:00,796 [INFO] sharp_har.train: C1_s6out_aug epoch 33/40: loss 0.5971, val macro-F1 0.9116, 0.545 s/step
# 2026-07-21 09:50:41,275 [INFO] sharp_har.train: C1_s6out_aug epoch 34/40: loss 0.5935, val macro-F1 0.8342, 0.547 s/step
# 2026-07-21 09:54:22,021 [INFO] sharp_har.train: C1_s6out_aug epoch 35/40: loss 0.5899, val macro-F1 0.8954, 0.547 s/step
# 2026-07-21 09:58:04,082 [INFO] sharp_har.train: C1_s6out_aug epoch 36/40: loss 0.5879, val macro-F1 0.9145, 0.550 s/step
# 2026-07-21 10:01:45,054 [INFO] sharp_har.train: C1_s6out_aug epoch 37/40: loss 0.5844, val macro-F1 0.9230, 0.547 s/step
# 2026-07-21 10:05:26,585 [INFO] sharp_har.train: C1_s6out_aug epoch 38/40: loss 0.5833, val macro-F1 0.9066, 0.548 s/step
# 2026-07-21 10:09:07,417 [INFO] sharp_har.train: C1_s6out_aug epoch 39/40: loss 0.5825, val macro-F1 0.9049, 0.548 s/step
# 2026-07-21 10:12:48,744 [INFO] sharp_har.train: C1_s6out_aug epoch 40/40: loss 0.5823, val macro-F1 0.9032, 0.548 s/step
# Train run finished: {'run_dir': PosixPath('/content/drive/MyDrive/sharp_har_runs/C1_s6out_aug'), 'best_val_macro_f1': 0.9229538715253002, 'history': [{'epoch': 1, 'train_loss': 1.6096148118376732, 'val_macro_f1': 0.33890299951620706, 'lr': 0.00020050000000000002, 's_per_step': 0.6150104224681854, 'epoch_seconds': 246.00416898727417}, {'epoch': 2, 'train_loss': 1.3897616773843766, 'val_macro_f1': 0.19496782709123908, 'lr': 0.00040050000000000003, 's_per_step': 0.5539942520856858, 'epoch_seconds': 221.5977008342743}, {'epoch': 3, 'train_loss': 1.281390821635723, 'val_macro_f1': 0.5401878849784876, 'lr': 0.0006005, 's_per_step': 0.5483781218528747, 'epoch_seconds': 219.3512487411499}, {'epoch': 4, 'train_loss': 1.2286590600013734, 'val_macro_f1': 0.34174234149893384, 'lr': 0.0008005, 's_per_step': 0.5493608701229096, 'epoch_seconds': 219.74434804916382}, {'epoch': 5, 'train_loss': 1.2176030412316323, 'val_macro_f1': 0.4073360314440353, 'lr': 0.001, 's_per_step': 0.5508016073703765, 'epoch_seconds': 220.32064294815063}, {'epoch': 6, 'train_loss': 1.135771014392376, 'val_macro_f1': 0.34337085678549095, 'lr': 0.0009979871469976197, 's_per_step': 0.5500076228380203, 'epoch_seconds': 220.00304913520813}, {'epoch': 7, 'train_loss': 1.0885713385045528, 'val_macro_f1': 0.40339532206022144, 'lr': 0.0009919647942993148, 's_per_step': 0.5525787830352783, 'epoch_seconds': 221.03151321411133}, {'epoch': 8, 'train_loss': 1.0625827477872372, 'val_macro_f1': 0.846310145154922, 'lr': 0.0009819814303479266, 's_per_step': 0.5489356452226639, 'epoch_seconds': 219.57425808906555}, {'epoch': 9, 'train_loss': 1.0211589597165585, 'val_macro_f1': 0.673630227753857, 'lr': 0.0009681174353198686, 's_per_step': 0.5490907371044159, 'epoch_seconds': 219.63629484176636}, {'epoch': 10, 'train_loss': 0.9864533495903015, 'val_macro_f1': 0.4317945562751004, 'lr': 0.0009504844339512095, 's_per_step': 0.5491745346784591, 'epoch_seconds': 219.66981387138367}, {'epoch': 11, 'train_loss': 0.9568823964893818, 'val_macro_f1': 0.4744003744003743, 'lr': 0.000929224396800933, 's_per_step': 0.5475894260406494, 'epoch_seconds': 219.03577041625977}, {'epoch': 12, 'train_loss': 0.9388575221598149, 'val_macro_f1': 0.4983956783956785, 'lr': 0.0009045084971874737, 's_per_step': 0.5489341515302658, 'epoch_seconds': 219.57366061210632}, {'epoch': 13, 'train_loss': 0.9091745324432849, 'val_macro_f1': 0.7126297498892068, 'lr': 0.0008765357330018055, 's_per_step': 0.5503904032707214, 'epoch_seconds': 220.15616130828857}, {'epoch': 14, 'train_loss': 0.8809294582903385, 'val_macro_f1': 0.7368414693752026, 'lr': 0.0008455313244934324, 's_per_step': 0.5487087279558182, 'epoch_seconds': 219.48349118232727}, {'epoch': 15, 'train_loss': 0.8503573769330979, 'val_macro_f1': 0.8585751923942577, 'lr': 0.0008117449009293668, 's_per_step': 0.5444753509759903, 'epoch_seconds': 217.79014039039612}, {'epoch': 16, 'train_loss': 0.823563840687275, 'val_macro_f1': 0.5398747869336105, 'lr': 0.0007754484907260512, 's_per_step': 0.546838806271553, 'epoch_seconds': 218.73552250862122}, {'epoch': 17, 'train_loss': 0.7971356923878193, 'val_macro_f1': 0.6792549922994255, 'lr': 0.0007369343312364993, 's_per_step': 0.5458764320611954, 'epoch_seconds': 218.35057282447815}, {'epoch': 18, 'train_loss': 0.7722124579548836, 'val_macro_f1': 0.8901565448874585, 'lr': 0.0006965125158269618, 's_per_step': 0.5482645380496979, 'epoch_seconds': 219.30581521987915}, {'epoch': 19, 'train_loss': 0.7470975178480148, 'val_macro_f1': 0.32305500416213107, 'lr': 0.0006545084971874737, 's_per_step': 0.5477376013994217, 'epoch_seconds': 219.09504055976868}, {'epoch': 20, 'train_loss': 0.7254648137092591, 'val_macro_f1': 0.6044444444444443, 'lr': 0.0006112604669781572, 's_per_step': 0.5503080040216446, 'epoch_seconds': 220.12320160865784}, {'epoch': 21, 'train_loss': 0.6984858591854572, 'val_macro_f1': 0.8471198488674216, 'lr': 0.0005671166329088278, 's_per_step': 0.5480007064342499, 'epoch_seconds': 219.20028257369995}, {'epoch': 22, ' ...

# %% [markdown]
# ## Training curves
#
# Per-epoch diagnostics read from the run's `history.csv` (§0.4). The
# panels adapt to the run: train loss and throughput always; fused val
# macro-F1 with the val-selected best epoch on CE runs (C0/C1/C2); the
# mandatory §6-C2 GRL monitoring pair (AR-set train accuracy vs λ ramp)
# on C2/C4; learning rate. Re-run this cell any time — it re-reads the
# CSV, so it also works on a resumed or still-running run.
#
# Related helpers in `sharp_har.viz`: `plot_confusion(csv)` for the
# harness `*_confusion.csv` files, `compare_runs({name: run_dir, ...})`
# to overlay a metric across configs (remember §0.5: differences under
# ~2 points are "comparable", not improvements).

# %%
# Thin runner: all plotting logic lives in sharp_har.viz.
from sharp_har.viz import plot_history

run_dir = CKPT_ROOT / cfg["name"]
plot_history(run_dir);

# %% [markdown]
# ## Archiving the definitive run notebook
#
# This notebook stays a **clean template** (outputs cleared on Git). The
# executed copy of a real run is a measured artifact and is committed
# verbatim, like the gate reports:
#
# 1. When the run (or a resumed segment) ends, download the executed
#    notebook (`File → Download → .ipynb`) **with its outputs**.
# 2. Commit it under `notebooks/runs/` as `YYYY-MM-DD_<config>.ipynb`
#    (e.g. `2026-07-16_c0_sharp.ipynb`); add a `_partN` suffix if one run
#    spans several resumed sessions. Never edit archived outputs.
# 3. The run's numeric artifacts still live in `ckpt_root/<name>/`
#    (`history.csv`, `run_meta.json`, checkpoints) — the archived
#    notebook is the human-readable record, not a data source.
#
# See `notebooks/runs/README.md` for the full convention.
