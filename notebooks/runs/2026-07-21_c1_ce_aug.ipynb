# %% [markdown]
# # 03 — Training runner, pre-configured: `c1_ce_aug` (C1-aug arm, S7-out, seed 42)
#
# A copy of the `03_train` template with `RUN` pre-set — open, run all.
#
# **What this run is** (team-approved 2026-07-20; pre-registered in
# `configs/c1_ce_aug.yaml` + `splits/CHANGELOG.md`): C1 with the additive
# `ce_amp` augmentation profile — amplitude scaling s ~ U(0.6, 1.5) at
# p=0.8, every other channel identical to the frozen CE profile. Same
# split, seed, init and batch order as C1, so the deliverable is the
# **paired** test delta vs the existing C1 row (no baseline rerun).
# Hypothesis: positive delta on both rotations (room/attenuation-framed);
# within the §0.5 ~2-pt band it reads "comparable".
#
# **Requires**: write access to your `ckpt_root` (the run creates
# `C1_aug/` — separate from `C1/`, auto-resume must never cross runs).
# The launch-check cell below fails on a stale clone (unknown `ce_amp`
# profile) BEFORE any training starts.
#
# Archive the executed copy under `notebooks/runs/` as
# `YYYY-MM-DD_c1_ce_aug.ipynb`, as for every run.

# %% [markdown]
# ## Environment setup
#
# This notebook is not one run per file. Instead:
#
# - one notebook = one runner
# - one config = one experiment
# - different people can use the same notebook with different config values
#
# In Colab, the notebook runs on a remote VM. If the repo is not already
# available there, this notebook will clone it from GitHub. It also stages
# data from the shared Drive archive into `/content/data` using the
# paths defined in `configs/paths.yaml`.

# %%
from pathlib import Path
import subprocess
import sys
import torch
import zipfile

REPO_URL = "https://github.com/FilippoIsoni/sharp-har.git"

# Locate or clone the repository root containing the sharp_har package.
# In Colab, the notebook may run from a temporary working directory.
cwd = Path.cwd().resolve()
if (cwd / "sharp_har").exists():
    REPO_DIR = cwd
elif (cwd.parent / "sharp_har").exists():
    REPO_DIR = cwd.parent
elif (cwd.parent.parent / "sharp_har").exists():
    REPO_DIR = cwd.parent.parent
else:
    REPO_DIR = Path("/content/sharp-har")
    if not REPO_DIR.exists():
        REPO_DIR.parent.mkdir(parents=True, exist_ok=True)
        subprocess.run(["git", "clone", REPO_URL, str(REPO_DIR)], check=True)

# After the clone, so the file actually exists on a fresh runtime.
# !pip install -q -r {REPO_DIR}/requirements.txt

sys.path.insert(0, str(REPO_DIR))

from google.colab import drive
from sharp_har.train import train_run
from sharp_har.utils import read_yaml

paths_cfg = read_yaml(REPO_DIR / "configs" / "paths.yaml")
drive_root = Path(paths_cfg["drive_root"])
stage_dir = Path(paths_cfg["stage_dir"])
CKPT_ROOT = Path(paths_cfg["ckpt_root"])

# Mount Drive unconditionally (idempotent): checkpoints are written to
# CKPT_ROOT on Drive even when the data is already staged on the VM.
drive.mount("/content/drive")

# Stage the zip archives if needed (same convention as 00_setup_smoke).
if not (stage_dir.exists() and any(stage_dir.rglob("*.txt"))):
    stage_dir.mkdir(parents=True, exist_ok=True)
    for zip_name in paths_cfg["zips"]:
        src = drive_root / zip_name
        dst = Path("/content") / zip_name
        print(f"copying {src} -> {dst}")
        subprocess.run(["cp", str(src), str(dst)], check=True)
        with zipfile.ZipFile(dst) as zf:
            zf.extractall(stage_dir)

print("Repo dir:", REPO_DIR)
print("sharp_har exists:", (REPO_DIR / "sharp_har").exists())
print("GPU available:", torch.cuda.is_available())
print("Stage dir:", stage_dir)
print("Checkpoint root:", CKPT_ROOT)
# Out:
# Mounted at /content/drive
# copying /content/drive/MyDrive/DATASET_SHARP/doppler_traces.zip -> /content/doppler_traces.zip
# copying /content/drive/MyDrive/DATASET_SHARP/doppler_traces_S4_S5.zip -> /content/doppler_traces_S4_S5.zip
# Repo dir: /content/sharp-har
# sharp_har exists: True
# GPU available: True
# Stage dir: /content/data
# Checkpoint root: /content/drive/MyDrive/sharp_har_runs

# %%
# GPU sanity check - run BEFORE launching training (see the C3 OOM incident).
# Expected on a clean runtime: no processes listed, ~0 MiB used. If not:
# Runtime -> Disconnect and delete runtime, then rerun from the top.
# !nvidia-smi

import torch
free, total = torch.cuda.mem_get_info()
print(f"free: {free/2**30:.2f} GiB / total: {total/2**30:.2f} GiB")
assert free / 2**30 > 10, (
    "GPU is not clean: less than 10 GiB free before training. "
    "Something else is holding memory - delete the runtime and start over."
)
print("GPU clean - OK to launch.")
# Out:
# Tue Jul 21 07:57:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             10W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# free: 14.46 GiB / total: 14.56 GiB
# GPU clean - OK to launch.

# %%
# Launch check (C1-aug arm): the clone must know the additive ce_amp
# profile (§3 amendment 2026-07-20) with the pre-registered values, and
# the frozen ce profile must be untouched. A stale clone fails HERE,
# not mid-run.
from sharp_har.augment import augment_cfg

_amp = augment_cfg("ce_amp")
assert _amp["p_amplitude_scaling"] == 0.8 and _amp["amplitude_range"] == (0.6, 1.5), _amp
_ce = augment_cfg("ce")
assert _ce["p_amplitude_scaling"] == 0.5 and _ce["amplitude_range"] == (0.8, 1.2), _ce
print("ce_amp profile OK:", {k: _amp[k] for k in ("p_amplitude_scaling", "amplitude_range")})
# Out:
# ce_amp profile OK: {'p_amplitude_scaling': 0.8, 'amplitude_range': (0.6, 1.5)}

# %% [markdown]
# ## Load config and launch the run
#
# Choose one config stem below and run the cell. The config name
# determines which experiment is executed.

# %%
RUN = "c1_ce_aug"  # pre-registered C1-aug arm (S7-out, seed 42) - do not change in-session
cfg = read_yaml(REPO_DIR / "configs" / f"{RUN}.yaml")
assert cfg["train"].get("augment_profile") == "ce_amp", cfg["train"]
assert (REPO_DIR / cfg["split_file"]).exists(), f"frozen {cfg['split_file']} missing from the clone (§0.1)"

print("Selected run:", RUN)
print("Config summary:")
print(cfg)

out = train_run(cfg, stage_dir=stage_dir, ckpt_dir=CKPT_ROOT, repo_dir=REPO_DIR)
print("Train run finished:", out)
# Out:
# 2026-07-21 07:57:56,551 [INFO] sharp_har.data: train: 81 traces, 53400 (window, antenna) samples (win=340, stride=100)
# 2026-07-21 07:57:56,569 [INFO] sharp_har.data: val: 9 traces, 1396 (window, antenna) samples (win=340, stride=340)
# Selected run: c1_ce_aug
# Config summary:
# {'name': 'C1_aug', 'seed': 42, 'protocol': 'P2-lab', 'split_file': 'splits/p2_lab.json', 'backbone': 'resnet_vb', 'd_enc': 256, 'n_att': 8, 'loss': {'type': 'ce', 'label_smoothing': 0.1}, 'adversary': {'type': None, 'target': 'ar_set', 'lambda_max': None, 'beta': None}, 'optim': {'name': 'adamw', 'lr': 0.001, 'wd': 0.0001, 'warmup_epochs': 5, 'scheduler': 'cosine'}, 'train': {'epoch_steps': 400, 'max_epochs': 40, 'batch_size': 256, 'sampler': 'uniform', 'augment_profile': 'ce_amp', 'amp': True, 'grad_clip': 1.0}, 'eval': {'select_metric': 'val_macro_f1', 'patience': 10}}
# 2026-07-21 08:02:09,384 [INFO] sharp_har.train: C1_aug epoch 1/40: loss 1.6151, val macro-F1 0.2543, 0.610 s/step
# 2026-07-21 08:05:57,333 [INFO] sharp_har.train: C1_aug epoch 2/40: loss 1.3581, val macro-F1 0.6032, 0.563 s/step
# 2026-07-21 08:09:42,695 [INFO] sharp_har.train: C1_aug epoch 3/40: loss 1.2579, val macro-F1 0.6061, 0.557 s/step
# 2026-07-21 08:13:27,109 [INFO] sharp_har.train: C1_aug epoch 4/40: loss 1.2155, val macro-F1 0.2415, 0.554 s/step
# 2026-07-21 08:17:12,574 [INFO] sharp_har.train: C1_aug epoch 5/40: loss 1.1424, val macro-F1 0.4956, 0.558 s/step
# 2026-07-21 08:20:56,436 [INFO] sharp_har.train: C1_aug epoch 6/40: loss 1.1017, val macro-F1 0.4476, 0.552 s/step
# 2026-07-21 08:24:36,036 [INFO] sharp_har.train: C1_aug epoch 7/40: loss 1.0521, val macro-F1 0.6291, 0.543 s/step
# 2026-07-21 08:28:18,925 [INFO] sharp_har.train: C1_aug epoch 8/40: loss 1.0264, val macro-F1 0.5101, 0.550 s/step
# 2026-07-21 08:32:00,643 [INFO] sharp_har.train: C1_aug epoch 9/40: loss 1.0002, val macro-F1 0.7717, 0.548 s/step
# 2026-07-21 08:35:43,028 [INFO] sharp_har.train: C1_aug epoch 10/40: loss 0.9694, val macro-F1 0.7004, 0.550 s/step
# 2026-07-21 08:39:24,733 [INFO] sharp_har.train: C1_aug epoch 11/40: loss 0.9466, val macro-F1 0.7948, 0.548 s/step
# 2026-07-21 08:43:05,241 [INFO] sharp_har.train: C1_aug epoch 12/40: loss 0.9248, val macro-F1 0.7414, 0.544 s/step
# 2026-07-21 08:46:48,703 [INFO] sharp_har.train: C1_aug epoch 13/40: loss 0.8945, val macro-F1 0.7697, 0.552 s/step
# 2026-07-21 08:50:29,430 [INFO] sharp_har.train: C1_aug epoch 14/40: loss 0.8724, val macro-F1 0.6609, 0.546 s/step
# 2026-07-21 08:54:12,206 [INFO] sharp_har.train: C1_aug epoch 15/40: loss 0.8427, val macro-F1 0.7801, 0.551 s/step
# 2026-07-21 08:57:51,456 [INFO] sharp_har.train: C1_aug epoch 16/40: loss 0.8157, val macro-F1 0.8075, 0.542 s/step
# 2026-07-21 09:01:33,584 [INFO] sharp_har.train: C1_aug epoch 17/40: loss 0.7842, val macro-F1 0.8375, 0.550 s/step
# 2026-07-21 09:05:16,694 [INFO] sharp_har.train: C1_aug epoch 18/40: loss 0.7535, val macro-F1 0.5415, 0.551 s/step
# 2026-07-21 09:08:57,597 [INFO] sharp_har.train: C1_aug epoch 19/40: loss 0.7311, val macro-F1 0.5959, 0.546 s/step
# 2026-07-21 09:12:40,974 [INFO] sharp_har.train: C1_aug epoch 20/40: loss 0.7072, val macro-F1 0.5317, 0.552 s/step
# 2026-07-21 09:16:21,396 [INFO] sharp_har.train: C1_aug epoch 21/40: loss 0.6898, val macro-F1 0.6748, 0.545 s/step
# 2026-07-21 09:20:04,659 [INFO] sharp_har.train: C1_aug epoch 22/40: loss 0.6736, val macro-F1 0.7426, 0.552 s/step
# 2026-07-21 09:23:45,952 [INFO] sharp_har.train: C1_aug epoch 23/40: loss 0.6605, val macro-F1 0.6960, 0.547 s/step
# 2026-07-21 09:27:27,929 [INFO] sharp_har.train: C1_aug epoch 24/40: loss 0.6475, val macro-F1 0.7543, 0.548 s/step
# 2026-07-21 09:31:10,995 [INFO] sharp_har.train: C1_aug epoch 25/40: loss 0.6398, val macro-F1 0.6906, 0.552 s/step
# 2026-07-21 09:34:52,356 [INFO] sharp_har.train: C1_aug epoch 26/40: loss 0.6303, val macro-F1 0.8709, 0.548 s/step
# 2026-07-21 09:38:35,189 [INFO] sharp_har.train: C1_aug epoch 27/40: loss 0.6215, val macro-F1 0.7637, 0.551 s/step
# 2026-07-21 09:42:16,022 [INFO] sharp_har.train: C1_aug epoch 28/40: loss 0.6145, val macro-F1 0.7870, 0.546 s/step
# 2026-07-21 09:45:57,768 [INFO] sharp_har.train: C1_aug epoch 29/40: loss 0.6069, val macro-F1 0.8095, 0.548 s/step
# 2026-07-21 09:49:39,729 [INFO] sharp_har.train: C1_aug epoch 30/40: loss 0.6012, val macro-F1 0.8376, 0.548 s/step
# 2026-07-21 09:53:20,456 [INFO] sharp_har.train: C1_aug epoch 31/40: loss 0.5952, val macro-F1 0.8830, 0.546 s/step
# 2026-07-21 09:57:02,547 [INFO] sharp_har.train: C1_aug epoch 32/40: loss 0.5899, val macro-F1 0.8207, 0.548 s/step
# 2026-07-21 10:00:43,384 [INFO] sharp_har.train: C1_aug epoch 33/40: loss 0.5861, val macro-F1 0.8427, 0.546 s/step
# 2026-07-21 10:04:24,689 [INFO] sharp_har.train: C1_aug epoch 34/40: loss 0.5831, val macro-F1 0.8595, 0.546 s/step
# 2026-07-21 10:08:05,119 [INFO] sharp_har.train: C1_aug epoch 35/40: loss 0.5799, val macro-F1 0.8671, 0.545 s/step
# 2026-07-21 10:11:44,524 [INFO] sharp_har.train: C1_aug epoch 36/40: loss 0.5770, val macro-F1 0.8698, 0.543 s/step
# 2026-07-21 10:15:26,068 [INFO] sharp_har.train: C1_aug epoch 37/40: loss 0.5744, val macro-F1 0.8709, 0.548 s/step
# 2026-07-21 10:19:08,226 [INFO] sharp_har.train: C1_aug epoch 38/40: loss 0.5741, val macro-F1 0.8707, 0.549 s/step
# 2026-07-21 10:22:49,548 [INFO] sharp_har.train: C1_aug epoch 39/40: loss 0.5739, val macro-F1 0.8642, 0.547 s/step
# 2026-07-21 10:26:28,978 [INFO] sharp_har.train: C1_aug epoch 40/40: loss 0.5739, val macro-F1 0.8599, 0.543 s/step
# Train run finished: {'run_dir': PosixPath('/content/drive/MyDrive/sharp_har_runs/C1_aug'), 'best_val_macro_f1': 0.8829610432307657, 'history': [{'epoch': 1, 'train_loss': 1.6151029390096665, 'val_macro_f1': 0.2543337811040747, 'lr': 0.00020050000000000002, 's_per_step': 0.6099022382497787, 'epoch_seconds': 243.9608952999115}, {'epoch': 2, 'train_loss': 1.358096467256546, 'val_macro_f1': 0.6032436600199299, 'lr': 0.00040050000000000003, 's_per_step': 0.5631306481361389, 'epoch_seconds': 225.25225925445557}, {'epoch': 3, 'train_loss': 1.2579443445801735, 'val_macro_f1': 0.6060652719265784, 'lr': 0.0006005, 's_per_step': 0.5571065461635589, 'epoch_seconds': 222.84261846542358}, {'epoch': 4, 'train_loss': 1.2155181297659874, 'val_macro_f1': 0.24147026748252687, 'lr': 0.0008005, 's_per_step': 0.5544728398323059, 'epoch_seconds': 221.78913593292236}, {'epoch': 5, 'train_loss': 1.1424025848507882, 'val_macro_f1': 0.4955558208423884, 'lr': 0.001, 's_per_step': 0.5579659861326217, 'epoch_seconds': 223.1863944530487}, {'epoch': 6, 'train_loss': 1.1017397537827491, 'val_macro_f1': 0.4476038282426072, 'lr': 0.0009979871469976197, 's_per_step': 0.5522730672359466, 'epoch_seconds': 220.90922689437866}, {'epoch': 7, 'train_loss': 1.052103642076254, 'val_macro_f1': 0.6291048847390146, 'lr': 0.0009919647942993148, 's_per_step': 0.5432879436016083, 'epoch_seconds': 217.3151774406433}, {'epoch': 8, 'train_loss': 1.0263811784982682, 'val_macro_f1': 0.5100975403321533, 'lr': 0.0009819814303479266, 's_per_step': 0.5504509443044663, 'epoch_seconds': 220.1803777217865}, {'epoch': 9, 'train_loss': 1.0002160754799843, 'val_macro_f1': 0.7716853427934139, 'lr': 0.0009681174353198686, 's_per_step': 0.5482043874263763, 'epoch_seconds': 219.28175497055054}, {'epoch': 10, 'train_loss': 0.969418000727892, 'val_macro_f1': 0.7003740825052783, 'lr': 0.0009504844339512095, 's_per_step': 0.5495933079719544, 'epoch_seconds': 219.83732318878174}, {'epoch': 11, 'train_loss': 0.9465870250761509, 'val_macro_f1': 0.7947662965300133, 'lr': 0.000929224396800933, 's_per_step': 0.5476528006792069, 'epoch_seconds': 219.06112027168274}, {'epoch': 12, 'train_loss': 0.9248271073400974, 'val_macro_f1': 0.7413576415948064, 'lr': 0.0009045084971874737, 's_per_step': 0.5441585475206375, 'epoch_seconds': 217.663419008255}, {'epoch': 13, 'train_loss': 0.8944667832553387, 'val_macro_f1': 0.7696771284271284, 'lr': 0.0008765357330018055, 's_per_step': 0.5518013328313828, 'epoch_seconds': 220.7205331325531}, {'epoch': 14, 'train_loss': 0.872401542365551, 'val_macro_f1': 0.6609415147119035, 'lr': 0.0008455313244934324, 's_per_step': 0.545924825668335, 'epoch_seconds': 218.36993026733398}, {'epoch': 15, 'train_loss': 0.8426996670663357, 'val_macro_f1': 0.7801144950527815, 'lr': 0.0008117449009293668, 's_per_step': 0.5507090139389038, 'epoch_seconds': 220.28360557556152}, {'epoch': 16, 'train_loss': 0.8157058984041214, 'val_macro_f1': 0.8075321906263071, 'lr': 0.0007754484907260512, 's_per_step': 0.5420360004901886, 'epoch_seconds': 216.81440019607544}, {'epoch': 17, 'train_loss': 0.7841634698212147, 'val_macro_f1': 0.8374775005112646, 'lr': 0.0007369343312364993, 's_per_step': 0.5496843272447586, 'epoch_seconds': 219.87373089790344}, {'epoch': 18, 'train_loss': 0.7534528952836991, 'val_macro_f1': 0.541499168920807, 'lr': 0.0006965125158269618, 's_per_step': 0.5509484672546386, 'epoch_seconds': 220.37938690185547}, {'epoch': 19, 'train_loss': 0.7311205638945103, 'val_macro_f1': 0.5958805742344688, 'lr': 0.0006545084971874737, 's_per_step': 0.5461816483736038, 'epoch_seconds': 218.47265934944153}, {'epoch': 20, 'train_loss': 0.7071595317125321, 'val_macro_f1': 0.5317493338338186, 'lr': 0.0006112604669781572, 's_per_step': 0.5518229877948762, 'epoch_seconds': 220.72919511795044}, {'epoch': 21, 'train_loss': 0.6898493158817292, 'val_macro_f1': 0.674817778648143, 'lr': 0.0005671166329088278, 's_per_step': 0.5447621297836304, 'epoch_seconds': 217.90485191345215}, {'epoch': 22, 'train_loss': 0.67 ...

# %% [markdown]
# ## Training curves
#
# Per-epoch diagnostics read from the run's `history.csv` (§0.4). The
# panels adapt to the run: train loss and throughput always; fused val
# macro-F1 with the val-selected best epoch on CE runs (C0/C1/C2); the
# mandatory §6-C2 GRL monitoring pair (AR-set train accuracy vs λ ramp)
# on C2/C4; learning rate. Re-run this cell any time — it re-reads the
# CSV, so it also works on a resumed or still-running run.
#
# Related helpers in `sharp_har.viz`: `plot_confusion(csv)` for the
# harness `*_confusion.csv` files, `compare_runs({name: run_dir, ...})`
# to overlay a metric across configs (remember §0.5: differences under
# ~2 points are "comparable", not improvements).

# %%
# Thin runner: all plotting logic lives in sharp_har.viz.
from sharp_har.viz import plot_history

run_dir = CKPT_ROOT / cfg["name"]
plot_history(run_dir);

# %% [markdown]
# ## Archiving the definitive run notebook
#
# This notebook stays a **clean template** (outputs cleared on Git). The
# executed copy of a real run is a measured artifact and is committed
# verbatim, like the gate reports:
#
# 1. When the run (or a resumed segment) ends, download the executed
#    notebook (`File → Download → .ipynb`) **with its outputs**.
# 2. Commit it under `notebooks/runs/` as `YYYY-MM-DD_<config>.ipynb`
#    (e.g. `2026-07-16_c0_sharp.ipynb`); add a `_partN` suffix if one run
#    spans several resumed sessions. Never edit archived outputs.
# 3. The run's numeric artifacts still live in `ckpt_root/<name>/`
#    (`history.csv`, `run_meta.json`, checkpoints) — the archived
#    notebook is the human-readable record, not a data source.
#
# See `notebooks/runs/README.md` for the full convention.
